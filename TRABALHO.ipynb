# %%
#importando pandas 
import pandas as pd

# %%
# Criando um data frame a partir do arquivo excel
df = pd.read_excel('dados_IGM-CFA_2017.xlsx',skiprows = 1)
#Exibindo 5 primeiras linhas 
df.head()
# Out:
#    Cód Mun  Codigouf  Codigomunicipio Estado                   Nome  \
# 0  3548708        35            48708     SP  SAO BERNARDO DO CAMPO
# 1  4110953        41            10953     PR           ITAIPULANDIA
# 2  3303302        33             3302     RJ                NITEROI
# 3  3520509        35            20509     SP             INDAIATUBA
# 4  4202008        42             2008     SC     BALNEARIO CAMBORIU
#
#    Capital (1=Sim;0=Não) Porte do Município  População 2016 (IBGE)  \
# 0                      0       Grande porte                 822242
# 1                      0    Pequeno porte 1                  10413
# 2                      0       Grande porte                 497883
# 3                      0       Grande porte                 235367
# 4                      0       Grande porte                 131727
#
#    Área da unidade territorial 2015 (km²) (IBGE Cidades)  \
# 0                                             409.53
# ...

# %%
#Exibindo 5 ultimas linhas
df.tail()
# Out:
#       Cód Mun  Codigouf  Codigomunicipio Estado                 Nome  \
# 5565  1720903        17            20903     TO           TAGUATINGA
# 5566  1720937        17            20937     TO  TAIPAS DO TOCANTINS
# 5567  1720978        17            20978     TO              TALISMA
# 5568  1721109        17            21109     TO           TOCANTINIA
# 5569  1722081        17            22081     TO         WANDERLANDIA
#
#       Capital (1=Sim;0=Não) Porte do Município  População 2016 (IBGE)  \
# 5565                      0    Pequeno porte 1                  16386
# 5566                      0    Pequeno porte 1                   2112
# 5567                      0    Pequeno porte 1                   2757
# 5568                      0    Pequeno porte 1                   7387
# 5569                      0    Pequeno porte 1                  11622
#
#       Área da unidade territorial 2015 (km²) (IBGE Cidades)  \
# 5565                                            2437.40
# ...

# %%
#tamanho do df em linhas e colunas 
df.shape
# Out:
# (5570, 48)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 48 columns):
# Cód Mun                                                                 5570 non-null int64
# Codigouf                                                                5570 non-null int64
# Codigomunicipio                                                         5570 non-null int64
# Estado                                                                  5570 non-null object
# Nome                                                                    5570 non-null object
# Capital (1=Sim;0=Não)                                                   5570 non-null int64
# Porte do Município                                                      5570 non-null object
# População 2016 (IBGE)                                                   5570 non-null int64
# Área da unidade territorial 2015 (km²) (IBGE Cidades)                   5570 non-null float64
# ...

# %%
# Analisando as colunas de texto usando o 'describe'
df.describe(include=[object])
#Em 'top' aparece aqueles que mais apareceram em cada variável, como MG que foi o estado que mais apareceu com 853 de 5570. 
#Bom Jesus foi a cidade que mais apareceu com a frequencia de 5.
# Out:
#        Estado       Nome Porte do Município Status em Fiscal  \
# count    5570       5570               5570             5570
# unique     27       5290                  4                3
# top        MG  BOM JESUS    Pequeno porte 1        Com dados
# freq      853          5               3810             4490
#
#                   Variável do outlier Status em Qualidade da Gestão  \
# count                              44                          5570
# unique                              3                             3
# top     Gastos per capita em educação                     Com dados
# freq                               19                          4348
#
#         Variável do outlier.1 Ranking sem outlier.1             Outlier  \
# count                      48                  3770                 105
# unique                      2                  3770                   5
# top     Servidores per capita                  753º  Médicos per capita
# ...

# %%
# Quais são as variaveis do outlier únicos
df['Variável do outlier'].unique()
# Out:
# array([nan, 'Gastos per capita em educação', 'Gastos per capita em saúde',
#        'Gastos per capita em saúde e educação'], dtype=object)

# %%
#Quem mais apareceu?
df['Variável do outlier'].value_counts()
# Out:
# Object `apareceu` not found.
# Gastos per capita em educação            19
# Gastos per capita em saúde               16
# Gastos per capita em saúde e educação     9
# Name: Variável do outlier, dtype: int64

# %%
Quem mais apareceu

# %%
#Quantidade de Munincipios por estado 
df['Estado'].value_counts()
# Out:
# MG    853
# SP    645
# RS    497
# BA    417
# PR    399
# SC    295
# GO    246
# PI    224
# PB    223
# MA    217
# PE    185
# CE    184
# RN    167
# PA    144
# MT    141
# TO    139
# AL    102
# RJ     92
# MS     79
# ES     78
# SE     75
# AM     62
# RO     52
# AC     22
# AP     16
# RR     15
# DF      1
# Name: Estado, dtype: int64

# %%
# Mágica do matplotlib
# %matplotlib inline
df['Estado'].value_counts().plot.bar()

# %%
# Maior população em 2016 segundo o IBGE
df[df['População 2016 (IBGE)'] == df['População 2016 (IBGE)'].max()]
# Out:
#     Cód Mun  Codigouf  Codigomunicipio Estado       Nome  \
# 22  3550308        35            50308     SP  SAO PAULO
#
#     Capital (1=Sim;0=Não) Porte do Município  População 2016 (IBGE)  \
# 22                      1       Grande porte               12038175
#
#     Área da unidade territorial 2015 (km²) (IBGE Cidades)  \
# 22                                            1521.11
#
#     Densidade demográfica 2010 (hab/km²) (IBGE Cidades)  \
# 22                                             7398.3
#
#                                     ...                                    \
# 22                                  ...
#
#     IDHM - 2017  Índice Desempenho - 2017  Ranking sem outlier.1  Outlier  \
# 22     0.863962                  0.740181                   292º      NaN
#
#        Status  Municípios com índice \n(1=Sim; 0 Não).2  IGM - 2017  \
# 22  Com dados                                         1    0.692107
#
#    Ranking sem outlier.2 Ranking Estadual  \
# ...

# %%
# Maior população em 2016 segundo o IBGE relacionadas ao porte do município
df.loc[df.groupby('Porte do Município')['População 2016 (IBGE)'].idxmax()]
# Out:
#       Cód Mun  Codigouf  Codigomunicipio Estado                     Nome  \
# 22    3550308        35            50308     SP                SAO PAULO
# 734   2412005        24            12005     RN  SAO GONCALO DO AMARANTE
# 5073  2805802        28             5802     SE        RIACHAO DO DANTAS
# 1229  3107307        31             7307     MG                 BOCAIUVA
#
#       Capital (1=Sim;0=Não) Porte do Município  População 2016 (IBGE)  \
# 22                        1       Grande porte               12038175
# 734                       0        Médio porte                  99724
# 5073                      0    Pequeno porte 1                  19995
# 1229                      0    Pequeno porte 2                  49891
#
#       Área da unidade territorial 2015 (km²) (IBGE Cidades)  \
# 22                                              1521.11
# 734                                              249.12
# 5073                                             531.70
# ...

# %%
# Gráficos
df['Capital (1=Sim;0=Não)'].value_counts()
# Out:
# 0    5543
# 1      27
# Name: Capital (1=Sim;0=Não), dtype: int64

# %%
# Cidades com o maior pib em 2013 a preços correntes 
df.loc[df.groupby('Estado')['PIB 2013 - a preços correntes per capita (IBGE)'].idxmax()]
# Out:
#       Cód Mun  Codigouf  Codigomunicipio Estado                       Nome  \
# 512   1200401        12              401     AC                 RIO BRANCO
# 840   2704708        27             4708     AL           MARECHAL DEODORO
# 2219  1301209        13             1209     AM                      COARI
# 2578  1600154        16              154     AP    PEDRA BRANCA DO AMAPARI
# 1061  2905404        29             5404     BA                      CAIRU
# 277   2304285        23             4285     CE                    EUSEBIO
# 23    5300108        53              108     DF                   BRASILIA
# 2926  3204302        32             4302     ES         PRESIDENTE KENNEDY
# 11    5205471        52             5471     GO            CHAPADAO DO CEU
# 3175  2110302        21            10302     MA    SANTO ANTONIO DOS LOPES
# 3569  3161908        31            61908     MG  SAO GONCALO DO RIO ABAIXO
# ...
